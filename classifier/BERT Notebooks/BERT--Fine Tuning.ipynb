# %%
! pip install transformers
from transformers import pipeline
! pip install transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 35.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 7.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 16.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from datasets import Dataset
from transformers import pipeline
#from transformers import AutoTokenizer, DataCollatorWithPadding
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoConfig, AutoModel, Pipeline, DataCollatorWithPadding
import numpy as np
import torch
import torch.nn as nn
from datasets import Dataset, load_metric
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification

# Load the CSV file into a Pandas dataframe
df = pd.read_csv("526892.csv", encoding="cp1252",index_col=0)

# Convert the dataframe to a Hugging Face datasets.Dataset object
dataset = Dataset.from_pandas(df)

# Tokenize the dataset
checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
def tokenize_function(example):
    return tokenizer(example["sentence"], truncation=True)
tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Add the labels to the tokenized dataset
def add_labels(example):
    example['labels'] = example.pop('label')
    return example
tokenized_dataset = tokenized_dataset.map(add_labels)

# Create a data collator
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# Take a batch from the tokenized dataset
batch = tokenized_dataset['sentence'][:1]

# Collate the batch using the data collator
batch = data_collator(batch)

# Tokenize the sentences
tokenized_sentences = tokenizer(df["sentence"].tolist(), padding=True, truncation=True)

# Combine the tokenized sentences with the labels
for key in tokenized_sentences:
    df[key] = tokenized_sentences[key]
df = df.drop(columns=["sentence"])
df = df.rename(columns={"label": "labels"})

# Convert the data to PyTorch tensors
data = {k: torch.tensor(v) for k, v in df.items()}

# Collate the batch using the data collator
batch = data_collator([df])

# Train the model with the batch
loss = model(**batch).loss
loss.backward()
optimizer.step()
# Out:
# ...
# Map:   0%|          | 0/356 [00:00<?, ? examples/s]
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7a97ff21cf44> in <cell line: 38>()
#      36
#      37 # Collate the batch using the data collator
# ---> 38 batch = data_collator(batch)
#      39
#      40 # Tokenize the sentences
#
# /usr/local/lib/python3.9/dist-packages/transformers/data/data_collator.py in __call__(self, features)
#     247
#     248     def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, Any]:
# --> 249         batch = self.tokenizer.pad(
#     250             features,
#     251             padding=self.padding,
#
# ...

# %%
import pandas as pd
from transformers import AutoTokenizer, DataCollatorWithPadding

# Load the data from CSV file into a Pandas DataFrame
data = pd.read_csv("data.csv", names=["sentence", "label"])

# Initialize the tokenizer and data collator
checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# Tokenize the sentences
tokenized_sentences = tokenizer(data["sentence"].tolist(), padding=True, truncation=True)

# Combine the tokenized sentences with the labels
for key in tokenized_sentences:
    da[key] = tokenized_sentences[key]
data = data.drop(columns=["sentence"])
data = data.rename(columns={"label": "labels"})

# Convert the data to PyTorch tensors
data = {k: torch.tensor(v) for k, v in data.items()}

# Collate the batch using the data collator
batch = data_collator([data])

# Train the model with the batch
loss = model(**batch).loss
loss.backward()
optimizer.step()
