# %% [markdown]
# # Unigram tokenization
#
# *   https://huggingface.co/learn/nlp-course/chapter6/7?fw=pt

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 10.3 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 10.8 MB/s eta 0:00:00
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 55.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 24.9 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.6 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers[sentencepiece])
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 100.2 MB/s eta 0:00:00
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.2 MB/s eta 0:00:00
# Collecting protobuf<=3.20.2 (from transformers[sentencepiece])
#   Downloading protobuf-3.20.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 6.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, sentencepiece, xxhash, protobuf, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets, evaluate
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 protobuf-3.20.2 responses-0.18.0 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.29.2 xxhash-3.2.0 yarl-1.9.2

# %%
from huggingface_hub.repocard import yaml
from datasets import load_dataset, Dataset, load_metric
import pandas as pd
import csv
import torch
import pandas as pd
import json

def dataframe_to_jsonl(dataframe, jsonl_file_path):
    with open(jsonl_file_path, 'w') as jsonl_file:
        for _, row in dataframe.iterrows():
            json_object = row.to_json(orient='columns')
            jsonl_file.write(json_object + '\n')

colnames = ['sentence', 'label', 'data', 'regex', 'subset']
train_df = pd.read_csv("COVID_Train_Set.csv", header=0, index_col=None, names=colnames, encoding="utf-8", delimiter=",", quoting=csv.QUOTE_NONE, error_bad_lines=False, skiprows=1, engine='python', na_values='None')
train_df
print(train_df)
print(train_df.iloc[:5])
#train_df = train_df.loc[train_df["sentence"] != 'None']
train_df = train_df.dropna()
train_df['regex'] = train_df['regex'].map({True: 'True', False: 'False'})
train_df['data'] = train_df['data'].astype(object)
test_df = pd.read_csv("COVID_Test_Set.csv", header=0, index_col=None, names=colnames, encoding="utf-8", delimiter=",", quoting=csv.QUOTE_NONE, error_bad_lines=False, skiprows=1, engine='python', na_values='None')
print(test_df)
print(test_df.iloc[:5])
test_df = test_df.dropna()
#test_df = test_df.loc[test_df["sentence"] != 'None']
test_df['regex'] = test_df['regex'].map({True: 'True', False: 'False'})
test_df['data'] = test_df['data'].astype(object)

# Example usage
  # Replace 'data.csv' with your DataFrame source
jsonl_file_path = 'train.jsonl'
dataframe_to_jsonl(train_df, jsonl_file_path)

jsonl_file_path = 'test.jsonl'
dataframe_to_jsonl(test_df, jsonl_file_path)

data_load = {"train": "train.jsonl", "test": "test.jsonl"}
# TypeError: expected str, bytes or os.PathLike object, not Dataset
covid_dataset = load_dataset("json", data_files=data_load)
# Out:
# Streaming output truncated to the last 5000 lines.
# Skipping line 28833: Expected 5 fields in line 28833, saw 13
# Skipping line 28835: Expected 5 fields in line 28835, saw 8
# Skipping line 28836: Expected 5 fields in line 28836, saw 9
# Skipping line 28837: Expected 5 fields in line 28837, saw 8
# Skipping line 28838: Expected 5 fields in line 28838, saw 11
# Skipping line 28839: Expected 5 fields in line 28839, saw 11
# Skipping line 28840: Expected 5 fields in line 28840, saw 10
# Skipping line 28842: Expected 5 fields in line 28842, saw 15
# Skipping line 28843: Expected 5 fields in line 28843, saw 11
# Skipping line 28844: Expected 5 fields in line 28844, saw 11
# Skipping line 28845: Expected 5 fields in line 28845, saw 10
# Skipping line 28846: Expected 5 fields in line 28846, saw 6
# Skipping line 28847: Expected 5 fields in line 28847, saw 13
# Skipping line 28849: Expected 5 fields in line 28849, saw 11
# Skipping line 28850: Expected 5 fields in line 28850, saw 9
# Skipping line 28851: Expected 5 fields in line 28851, saw 11
# Skipping line 28852: Expected 5 fields in line 28852, saw 8
# Skipping line 28853: Expected 5 fields in line 28853, saw 7
# Skipping line 28854: Expected 5 fields in line 28854, saw 12
# Skipping line 28868: Expected 5 fields in line 28868, saw 12
# Skipping line 28872: Expected 5 fields in line 28872, saw 8
# Skipping line 28873: Expected 5 fields in line 28873, saw 7
# Skipping line 28874: Expected 5 fields in line 28874, saw 13
# Skipping line 28875: Expected 5 fields in line 28875, saw 6
# Skipping line 28876: Expected 5 fields in line 28876, saw 10
# Skipping line 28879: Expected 5 fields in line 28879, saw 14
# Skipping line 28880: Expected 5 fields in line 28880, saw 17
# Skipping line 28881: Expected 5 fields in line 28881, saw 10
# Skipping line 28882: Expected 5 fields in line 28882, saw 7
# Skipping line 28883: Expected 5 fields in line 28883, saw 16
# Skipping line 28884: Expected 5 fields in line 28884, saw 14
# Skipping line 28890: Expected 5 fields in line 28890, saw 13
# Skipping line 28897: Expected 5 fields in line 28897, saw 8
# Skipping line 28903: Expected 5 fields in line 28903, saw 16
# Skipping line 28911: Expected 5 fields in line 28911, saw 42
# Skipping line 28914: Expected 5 fields in line 28914, saw 17
# Skipping line 28917: Expected 5 fields in line 28917, saw 9
# Skipping line 28989: Expected 5 fields in line 28989, saw 6
# Skipping line 28990: Expected 5 fields in line 28990, saw 6
# Skipping line 28991: Expected 5 fields in line 28991, saw 6
# Skipping line 28992: Expected 5 fields in line 28992, saw 6
# Skipping line 28993: Expected 5 fields in line 28993, saw 6
# Skipping line 28994: Expected 5 fields in line 28994, saw 6
# Skipping line 28995: Expected 5 fields in line 28995, saw 6
# Skipping line 28996: Expected 5 fields in line 28996, saw 6
# Skipping line 28997: Expected 5 fields in line 28997, saw 6
# Skipping line 28998: Expected 5 fields in line 28998, saw 6
# Skipping line 29008: Expected 5 fields in line 29008, saw 6
# Skipping line 29045: Expected 5 fields in line 29045, saw 7
# Skipping line 29047: Expected 5 fields in line 29047, saw 6
# Skipping line 29058: Expected 5 fields in line 29058, saw 9
# Skipping line 29159: Expected 5 fields in line 29159, saw 7
# Skipping line 29160: Expected 5 fields in line 29160, saw 9
# Skipping line 29161: Expected 5 fields in line 29161, saw 6
# Skipping line 29162: Expected 5 fields in line 29162, saw 6
# Skipping line 29165: Expected 5 fields in line 29165, saw 10
# Skipping line 29167: Expected 5 fields in line 29167, saw 16
# Skipping line 29169: Expected 5 fields in line 29169, saw 16
# Skipping line 29171: Expected 5 fields in line 29171, saw 7
# Skipping line 29173: Expected 5 fields in line 29173, saw 21
# Skipping line 29175: Expected 5 fields in line 29175, saw 10
# Skipping line 29176: Expected 5 fields in line 29176, saw 9
# Skipping line 29177: Expected 5 fields in line 29177, saw 16
# Skipping line 29179: Expected 5 fields in line 29179, saw 9
# Skipping line 29180: Expected 5 fields in line 29180, saw 8
# Skipping line 29183: Expected 5 fields in line 29183, saw 8
# Skipping line 29189: Expected 5 fields in line 29189, saw 6
# Skipping line 29192: Expected 5 fields in line 29192, saw 15
# Skipping line 29195: Expected 5 fields in line 29195, saw 7
# Skipping line 29196: Expected 5 fields in line 29196, saw 6
# Skipping line 29198: Expected 5 fields in line 29198, saw 6
# Skipping line 29199: Expected 5 fields in line 29199, saw 8
# Skipping line 29200: Expected 5 fields in line 29200, saw 8
# Skipping line 29201: Expected 5 fields in line 29201, saw 9
# Skipping line 29205: Expected 5 fields in line 29205, saw 10
# Skipping line 29206: Expected 5 fields in line 29206, saw 8
# Skipping line 29207: Expected 5 fields in line 29207, saw 7
# Skipping line 29208: Expected 5 fields in line 29208, saw 15
# Skipping line 29209: Expected 5 fields in line 29209, saw 15
# Skipping line 29210: Expected 5 fields in line 29210, saw 14
# Skipping line 29211: Expected 5 fields in line 29211, saw 11
# Skipping line 29213: Expected 5 fields in line 29213, saw 15
# Skipping line 29214: Expected 5 fields in line 29214, saw 14
# Skipping line 29215: Expected 5 fields in line 29215, saw 11
# Skipping line 29216: Expected 5 fields in line 29216, saw 6
# Skipping line 29217: Expected 5 fields in line 29217, saw 8
# Skipping line 29218: Expected 5 fields in line 29218, saw 12
# Skipping line 29219: Expected 5 fields in line 29219, saw 7
# Skipping line 29221: Expected 5 fields in line 29221, saw 7
# Skipping line 29222: Expected 5 fields in line 29222, saw 6
# Skipping line 29223: Expected 5 fields in line 29223, saw 6
# Skipping line 29225: Expected 5 fields in line 29225, saw 56
# Skipping line 29238: Expected 5 fields in line 29238, saw 14
# Skipping line 29239: Expected 5 fields in line 29239, saw 8
# Skipping line 29241: Expected 5 fields in line 29241, saw 16
# Skipping line 29243: Expected 5 fields in line 29243, saw 8
# Skipping line 29245: Expected 5 fields in line 29245, saw 6
# Skipping line 29246: Expected 5 fields in line 29246, saw 7
# Skipping line 29247: Expected 5 fields in line 29247, saw 7
# Skipping line 29248: Expected 5 fields in line 29248, saw 7
# Skipping line 29250: Expected 5 fields in line 29250, saw 7
# Skipping line 29255: Expected 5 fields in line 29255, saw 17
# Skipping line 29256: Expected 5 fields in line 29256, saw 6
# Skipping line 29258: Expected 5 fields in line 29258, saw 15
# Skipping line 29259: Expected 5 fields in line 29259, saw 6
# Skipping line 29261: Expected 5 fields in line 29261, saw 7
# Skipping line 29262: Expected 5 fields in line 29262, saw 7
# Skipping line 29265: Expected 5 fields in line 29265, saw 6
# Skipping line 29279: Expected 5 fields in line 29279, saw 8
# Skipping line 29288: Expected 5 fields in line 29288, saw 6
# Skipping line 29292: Expected 5 fields in line 29292, saw 7
# Skipping line 29293: Expected 5 fields in line 29293, saw 6
# Skipping line 29298: Expected 5 fields in line 29298, saw 6
# Skipping line 29314: Expected 5 fields in line 29314, saw 10
# Skipping line 29315: Expected 5 fields in line 29315, saw 15
# Skipping line 29316: Expected 5 fields in line 29316, saw 9
# Skipping line 29317: Expected 5 fields in line 29317, saw 6
# Skipping line 29318: Expected 5 fields in line 29318, saw 6
# Skipping line 29319: Expected 5 fields in line 29319, saw 7
# Skipping line 29320: Expected 5 fields in line 29320, saw 11
# Skipping line 29324: Expected 5 fields in line 29324, saw 9
# Skipping line 29325: Expected 5 fields in line 29325, saw 12
# Skipping line 29326: Expected 5 fields in line 29326, saw 8
# Skipping line 29327: Expected 5 fields in line 29327, saw 11
# Skipping line 29328: Expected 5 fields in line 29328, saw 8
# Skipping line 29335: Expected 5 fields in line 29335, saw 8
# Skipping line 29336: Expected 5 fields in line 29336, saw 8
# Skipping line 29337: Expected 5 fields in line 29337, saw 6
# Skipping line 29338: Expected 5 fields in line 29338, saw 6
# Skipping line 29339: Expected 5 fields in line 29339, saw 8
# Skipping line 29340: Expected 5 fields in line 29340, saw 14
# Skipping line 29341: Expected 5 fields in line 29341, saw 8
# Skipping line 29342: Expected 5 fields in line 29342, saw 16
# Skipping line 29343: Expected 5 fields in line 29343, saw 8
# Skipping line 29344: Expected 5 fields in line 29344, saw 7
# Skipping line 29345: Expected 5 fields in line 29345, saw 12
# Skipping line 29349: Expected 5 fields in line 29349, saw 22
# Skipping line 29351: Expected 5 fields in line 29351, saw 8
# Skipping line 29352: Expected 5 fields in line 29352, saw 9
# Skipping line 29353: Expected 5 fields in line 29353, saw 6
# Skipping line 29356: Expected 5 fields in line 29356, saw 9
# Skipping line 29360: Expected 5 fields in line 29360, saw 7
# Skipping line 29362: Expected 5 fields in line 29362, saw 20
# Skipping line 29363: Expected 5 fields in line 29363, saw 17
# Skipping line 29364: Expected 5 fields in line 29364, saw 6
# Skipping line 29366: Expected 5 fields in line 29366, saw 29
# Skipping line 29367: Expected 5 fields in line 29367, saw 7
# Skipping line 29371: Expected 5 fields in line 29371, saw 19
# Skipping line 29374: Expected 5 fields in line 29374, saw 38
# Skipping line 29375: Expected 5 fields in line 29375, saw 24
# Skipping line 29376: Expected 5 fields in line 29376, saw 9
# Skipping line 29378: Expected 5 fields in line 29378, saw 6
# Skipping line 29380: Expected 5 fields in line 29380, saw 20
# Skipping line 29381: Expected 5 fields in line 29381, saw 18
# Skipping line 29383: Expected 5 fields in line 29383, saw 8
# Skipping line 29385: Expected 5 fields in line 29385, saw 20
# Skipping line 29386: Expected 5 fields in line 29386, saw 8
# Skipping line 29387: Expected 5 fields in line 29387, saw 9
# Skipping line 29388: Expected 5 fields in line 29388, saw 9
# Skipping line 29391: Expected 5 fields in line 29391, saw 16
# Skipping line 29393: Expected 5 fields in line 29393, saw 45
# Skipping line 29394: Expected 5 fields in line 29394, saw 19
# Skipping line 29395: Expected 5 fields in line 29395, saw 9
# Skipping line 29398: Expected 5 fields in line 29398, saw 8
# Skipping line 29399: Expected 5 fields in line 29399, saw 7
# Skipping line 29400: Expected 5 fields in line 29400, saw 27
# Skipping line 29401: Expected 5 fields in line 29401, saw 18
# Skipping line 29402: Expected 5 fields in line 29402, saw 17
# Skipping line 29404: Expected 5 fields in line 29404, saw 17
# Skipping line 29405: Expected 5 fields in line 29405, saw 8
# Skipping line 29406: Expected 5 fields in line 29406, saw 9
# Skipping line 29409: Expected 5 fields in line 29409, saw 16
# Skipping line 29411: Expected 5 fields in line 29411, saw 43
# Skipping line 29413: Expected 5 fields in line 29413, saw 36
# Skipping line 29416: Expected 5 fields in line 29416, saw 23
# Skipping line 29417: Expected 5 fields in line 29417, saw 19
# Skipping line 29419: Expected 5 fields in line 29419, saw 6
# Skipping line 29422: Expected 5 fields in line 29422, saw 26
# Skipping line 29423: Expected 5 fields in line 29423, saw 14
# Skipping line 29424: Expected 5 fields in line 29424, saw 9
# Skipping line 29425: Expected 5 fields in line 29425, saw 9
# Skipping line 29428: Expected 5 fields in line 29428, saw 22
# Skipping line 29430: Expected 5 fields in line 29430, saw 18
# Skipping line 29431: Expected 5 fields in line 29431, saw 10
# Skipping line 29432: Expected 5 fields in line 29432, saw 33
# Skipping line 29434: Expected 5 fields in line 29434, saw 17
# Skipping line 29435: Expected 5 fields in line 29435, saw 6
# Skipping line 29437: Expected 5 fields in line 29437, saw 31
# Skipping line 29440: Expected 5 fields in line 29440, saw 24
# Skipping line 29441: Expected 5 fields in line 29441, saw 24
# Skipping line 29442: Expected 5 fields in line 29442, saw 9
# Skipping line 29444: Expected 5 fields in line 29444, saw 7
# Skipping line 29446: Expected 5 fields in line 29446, saw 23
# Skipping line 29447: Expected 5 fields in line 29447, saw 21
# Skipping line 29449: Expected 5 fields in line 29449, saw 18
# Skipping line 29451: Expected 5 fields in line 29451, saw 25
# Skipping line 29452: Expected 5 fields in line 29452, saw 9
# Skipping line 29453: Expected 5 fields in line 29453, saw 9
# Skipping line 29454: Expected 5 fields in line 29454, saw 9
# Skipping line 29457: Expected 5 fields in line 29457, saw 28
# Skipping line 29459: Expected 5 fields in line 29459, saw 18
# Skipping line 29460: Expected 5 fields in line 29460, saw 22
# Skipping line 29461: Expected 5 fields in line 29461, saw 7
# Skipping line 29463: Expected 5 fields in line 29463, saw 17
# Skipping line 29465: Expected 5 fields in line 29465, saw 9
# Skipping line 29468: Expected 5 fields in line 29468, saw 17
# Skipping line 29470: Expected 5 fields in line 29470, saw 15
# Skipping line 29471: Expected 5 fields in line 29471, saw 8
# Skipping line 29472: Expected 5 fields in line 29472, saw 9
# Skipping line 29475: Expected 5 fields in line 29475, saw 7
# Skipping line 29477: Expected 5 fields in line 29477, saw 29
# Skipping line 29478: Expected 5 fields in line 29478, saw 13
# Skipping line 29479: Expected 5 fields in line 29479, saw 25
# Skipping line 29482: Expected 5 fields in line 29482, saw 31
# Skipping line 29483: Expected 5 fields in line 29483, saw 6
# Skipping line 29485: Expected 5 fields in line 29485, saw 28
# Skipping line 29487: Expected 5 fields in line 29487, saw 22
# Skipping line 29489: Expected 5 fields in line 29489, saw 21
# Skipping line 29490: Expected 5 fields in line 29490, saw 10
# Skipping line 29491: Expected 5 fields in line 29491, saw 9
# Skipping line 29493: Expected 5 fields in line 29493, saw 7
# Skipping line 29495: Expected 5 fields in line 29495, saw 27
# Skipping line 29496: Expected 5 fields in line 29496, saw 26
# Skipping line 29498: Expected 5 fields in line 29498, saw 17
# Skipping line 29500: Expected 5 fields in line 29500, saw 39
# Skipping line 29501: Expected 5 fields in line 29501, saw 7
# Skipping line 29502: Expected 5 fields in line 29502, saw 9
# Skipping line 29503: Expected 5 fields in line 29503, saw 9
# Skipping line 29506: Expected 5 fields in line 29506, saw 14
# Skipping line 29508: Expected 5 fields in line 29508, saw 20
# Skipping line 29509: Expected 5 fields in line 29509, saw 28
# Skipping line 29510: Expected 5 fields in line 29510, saw 6
# Skipping line 29511: Expected 5 fields in line 29511, saw 9
# Skipping line 29515: Expected 5 fields in line 29515, saw 24
# Skipping line 29516: Expected 5 fields in line 29516, saw 33
# Skipping line 29519: Expected 5 fields in line 29519, saw 11
# Skipping line 29520: Expected 5 fields in line 29520, saw 38
# Skipping line 29524: Expected 5 fields in line 29524, saw 82
# Skipping line 29525: Expected 5 fields in line 29525, saw 12
# Skipping line 29527: Expected 5 fields in line 29527, saw 12
# Skipping line 29529: Expected 5 fields in line 29529, saw 18
# Skipping line 29530: Expected 5 fields in line 29530, saw 9
# Skipping line 29531: Expected 5 fields in line 29531, saw 9
# Skipping line 29533: Expected 5 fields in line 29533, saw 20
# Skipping line 29535: Expected 5 fields in line 29535, saw 33
# Skipping line 29537: Expected 5 fields in line 29537, saw 24
# Skipping line 29538: Expected 5 fields in line 29538, saw 32
# Skipping line 29539: Expected 5 fields in line 29539, saw 9
# Skipping line 29543: Expected 5 fields in line 29543, saw 16
# Skipping line 29544: Expected 5 fields in line 29544, saw 21
# Skipping line 29548: Expected 5 fields in line 29548, saw 20
# Skipping line 29549: Expected 5 fields in line 29549, saw 28
# Skipping line 29550: Expected 5 fields in line 29550, saw 9
# Skipping line 29552: Expected 5 fields in line 29552, saw 9
# Skipping line 29553: Expected 5 fields in line 29553, saw 6
# Skipping line 29554: Expected 5 fields in line 29554, saw 54
# Skipping line 29555: Expected 5 fields in line 29555, saw 9
# Skipping line 29557: Expected 5 fields in line 29557, saw 15
# Skipping line 29559: Expected 5 fields in line 29559, saw 36
# Skipping line 29560: Expected 5 fields in line 29560, saw 6
# Skipping line 29561: Expected 5 fields in line 29561, saw 9
# Skipping line 29563: Expected 5 fields in line 29563, saw 19
# Skipping line 29565: Expected 5 fields in line 29565, saw 17
# Skipping line 29567: Expected 5 fields in line 29567, saw 19
# Skipping line 29569: Expected 5 fields in line 29569, saw 21
# Skipping line 29571: Expected 5 fields in line 29571, saw 9
# Skipping line 29572: Expected 5 fields in line 29572, saw 9
# Skipping line 29574: Expected 5 fields in line 29574, saw 18
# Skipping line 29576: Expected 5 fields in line 29576, saw 32
# Skipping line 29577: Expected 5 fields in line 29577, saw 13
# Skipping line 29580: Expected 5 fields in line 29580, saw 34
# Skipping line 29581: Expected 5 fields in line 29581, saw 49
# Skipping line 29583: Expected 5 fields in line 29583, saw 11
# Skipping line 29585: Expected 5 fields in line 29585, saw 19
# Skipping line 29586: Expected 5 fields in line 29586, saw 16
# Skipping line 29587: Expected 5 fields in line 29587, saw 9
# Skipping line 29588: Expected 5 fields in line 29588, saw 9
# Skipping line 29591: Expected 5 fields in line 29591, saw 9
# Skipping line 29593: Expected 5 fields in line 29593, saw 24
# Skipping line 29594: Expected 5 fields in line 29594, saw 10
# Skipping line 29595: Expected 5 fields in line 29595, saw 10
# Skipping line 29596: Expected 5 fields in line 29596, saw 7
# Skipping line 29598: Expected 5 fields in line 29598, saw 39
# Skipping line 29599: Expected 5 fields in line 29599, saw 7
# Skipping line 29600: Expected 5 fields in line 29600, saw 9
# Skipping line 29603: Expected 5 fields in line 29603, saw 22
# Skipping line 29605: Expected 5 fields in line 29605, saw 14
# Skipping line 29606: Expected 5 fields in line 29606, saw 46
# Skipping line 29609: Expected 5 fields in line 29609, saw 22
# Skipping line 29610: Expected 5 fields in line 29610, saw 11
# Skipping line 29613: Expected 5 fields in line 29613, saw 29
# Skipping line 29614: Expected 5 fields in line 29614, saw 22
# Skipping line 29615: Expected 5 fields in line 29615, saw 9
# Skipping line 29617: Expected 5 fields in line 29617, saw 6
# Skipping line 29619: Expected 5 fields in line 29619, saw 23
# Skipping line 29620: Expected 5 fields in line 29620, saw 15
# Skipping line 29622: Expected 5 fields in line 29622, saw 19
# Skipping line 29624: Expected 5 fields in line 29624, saw 25
# Skipping line 29625: Expected 5 fields in line 29625, saw 8
# Skipping line 29626: Expected 5 fields in line 29626, saw 9
# Skipping line 29628: Expected 5 fields in line 29628, saw 40
# Skipping line 29631: Expected 5 fields in line 29631, saw 48
# Skipping line 29632: Expected 5 fields in line 29632, saw 9
# Skipping line 29633: Expected 5 fields in line 29633, saw 9
# Skipping line 29635: Expected 5 fields in line 29635, saw 16
# Skipping line 29637: Expected 5 fields in line 29637, saw 27
# Skipping line 29638: Expected 5 fields in line 29638, saw 10
# Skipping line 29640: Expected 5 fields in line 29640, saw 18
# Skipping line 29642: Expected 5 fields in line 29642, saw 21
# Skipping line 29643: Expected 5 fields in line 29643, saw 6
# Skipping line 29644: Expected 5 fields in line 29644, saw 9
# Skipping line 29646: Expected 5 fields in line 29646, saw 28
# Skipping line 29648: Expected 5 fields in line 29648, saw 27
# Skipping line 29651: Expected 5 fields in line 29651, saw 27
# Skipping line 29652: Expected 5 fields in line 29652, saw 9
# Skipping line 29656: Expected 5 fields in line 29656, saw 33
# Skipping line 29657: Expected 5 fields in line 29657, saw 19
# Skipping line 29659: Expected 5 fields in line 29659, saw 8
# Skipping line 29661: Expected 5 fields in line 29661, saw 25
# Skipping line 29662: Expected 5 fields in line 29662, saw 35
# Skipping line 29663: Expected 5 fields in line 29663, saw 9
# Skipping line 29665: Expected 5 fields in line 29665, saw 19
# Skipping line 29667: Expected 5 fields in line 29667, saw 23
# Skipping line 29668: Expected 5 fields in line 29668, saw 8
# Skipping line 29670: Expected 5 fields in line 29670, saw 27
# Skipping line 29672: Expected 5 fields in line 29672, saw 9
# Skipping line 29673: Expected 5 fields in line 29673, saw 7
# Skipping line 29674: Expected 5 fields in line 29674, saw 9
# Skipping line 29676: Expected 5 fields in line 29676, saw 22
# Skipping line 29678: Expected 5 fields in line 29678, saw 28
# Skipping line 29680: Expected 5 fields in line 29680, saw 27
# Skipping line 29681: Expected 5 fields in line 29681, saw 9
# Skipping line 29684: Expected 5 fields in line 29684, saw 28
# Skipping line 29685: Expected 5 fields in line 29685, saw 18
# Skipping line 29687: Expected 5 fields in line 29687, saw 14
# Skipping line 29689: Expected 5 fields in line 29689, saw 23
# Skipping line 29690: Expected 5 fields in line 29690, saw 24
# Skipping line 29691: Expected 5 fields in line 29691, saw 9
# Skipping line 29693: Expected 5 fields in line 29693, saw 14
# Skipping line 29695: Expected 5 fields in line 29695, saw 43
# Skipping line 29696: Expected 5 fields in line 29696, saw 8
# Skipping line 29698: Expected 5 fields in line 29698, saw 24
# Skipping line 29699: Expected 5 fields in line 29699, saw 7
# Skipping line 29700: Expected 5 fields in line 29700, saw 30
# Skipping line 29702: Expected 5 fields in line 29702, saw 9
# Skipping line 29704: Expected 5 fields in line 29704, saw 28
# Skipping line 29707: Expected 5 fields in line 29707, saw 21
# Skipping line 29708: Expected 5 fields in line 29708, saw 22
# Skipping line 29709: Expected 5 fields in line 29709, saw 9
# Skipping line 29711: Expected 5 fields in line 29711, saw 14
# Skipping line 29714: Expected 5 fields in line 29714, saw 48
# Skipping line 29715: Expected 5 fields in line 29715, saw 10
# Skipping line 29717: Expected 5 fields in line 29717, saw 26
# Skipping line 29719: Expected 5 fields in line 29719, saw 26
# Skipping line 29720: Expected 5 fields in line 29720, saw 9
# Skipping line 29721: Expected 5 fields in line 29721, saw 9
# Skipping line 29723: Expected 5 fields in line 29723, saw 19
# Skipping line 29726: Expected 5 fields in line 29726, saw 27
# Skipping line 29727: Expected 5 fields in line 29727, saw 22
# Skipping line 29728: Expected 5 fields in line 29728, saw 9
# Skipping line 29730: Expected 5 fields in line 29730, saw 12
# Skipping line 29732: Expected 5 fields in line 29732, saw 35
# Skipping line 29733: Expected 5 fields in line 29733, saw 17
# Skipping line 29735: Expected 5 fields in line 29735, saw 9
# Skipping line 29737: Expected 5 fields in line 29737, saw 42
# Skipping line 29738: Expected 5 fields in line 29738, saw 10
# Skipping line 29739: Expected 5 fields in line 29739, saw 9
# Skipping line 29740: Expected 5 fields in line 29740, saw 9
# Skipping line 29743: Expected 5 fields in line 29743, saw 28
# Skipping line 29745: Expected 5 fields in line 29745, saw 27
# Skipping line 29746: Expected 5 fields in line 29746, saw 6
# Skipping line 29747: Expected 5 fields in line 29747, saw 26
# Skipping line 29750: Expected 5 fields in line 29750, saw 28
# Skipping line 29751: Expected 5 fields in line 29751, saw 21
# Skipping line 29753: Expected 5 fields in line 29753, saw 14
# Skipping line 29755: Expected 5 fields in line 29755, saw 24
# Skipping line 29756: Expected 5 fields in line 29756, saw 10
# Skipping line 29757: Expected 5 fields in line 29757, saw 9
# Skipping line 29759: Expected 5 fields in line 29759, saw 19
# Skipping line 29761: Expected 5 fields in line 29761, saw 33
# Skipping line 29762: Expected 5 fields in line 29762, saw 7
# Skipping line 29764: Expected 5 fields in line 29764, saw 12
# Skipping line 29766: Expected 5 fields in line 29766, saw 13
# Skipping line 29767: Expected 5 fields in line 29767, saw 8
# Skipping line 29768: Expected 5 fields in line 29768, saw 9
# Skipping line 29770: Expected 5 fields in line 29770, saw 29
# Skipping line 29774: Expected 5 fields in line 29774, saw 22
# Skipping line 29775: Expected 5 fields in line 29775, saw 28
# Skipping line 29776: Expected 5 fields in line 29776, saw 9
# Skipping line 29777: Expected 5 fields in line 29777, saw 9
# Skipping line 29780: Expected 5 fields in line 29780, saw 17
# Skipping line 29782: Expected 5 fields in line 29782, saw 11
# Skipping line 29783: Expected 5 fields in line 29783, saw 18
# Skipping line 29784: Expected 5 fields in line 29784, saw 10
# Skipping line 29786: Expected 5 fields in line 29786, saw 38
# Skipping line 29787: Expected 5 fields in line 29787, saw 8
# Skipping line 29788: Expected 5 fields in line 29788, saw 9
# Skipping line 29791: Expected 5 fields in line 29791, saw 33
# Skipping line 29793: Expected 5 fields in line 29793, saw 19
# Skipping line 29794: Expected 5 fields in line 29794, saw 36
# Skipping line 29795: Expected 5 fields in line 29795, saw 9
# Skipping line 29798: Expected 5 fields in line 29798, saw 6
# Skipping line 29799: Expected 5 fields in line 29799, saw 20
# Skipping line 29800: Expected 5 fields in line 29800, saw 29
# Skipping line 29801: Expected 5 fields in line 29801, saw 11
# Skipping line 29803: Expected 5 fields in line 29803, saw 26
# Skipping line 29804: Expected 5 fields in line 29804, saw 15
# Skipping line 29805: Expected 5 fields in line 29805, saw 9
# Skipping line 29808: Expected 5 fields in line 29808, saw 17
# Skipping line 29809: Expected 5 fields in line 29809, saw 6
# Skipping line 29810: Expected 5 fields in line 29810, saw 19
# Skipping line 29811: Expected 5 fields in line 29811, saw 19
# Skipping line 29812: Expected 5 fields in line 29812, saw 24
# Skipping line 29814: Expected 5 fields in line 29814, saw 19
# Skipping line 29815: Expected 5 fields in line 29815, saw 10
# Skipping line 29817: Expected 5 fields in line 29817, saw 29
# Skipping line 29820: Expected 5 fields in line 29820, saw 35
# Skipping line 29821: Expected 5 fields in line 29821, saw 29
# Skipping line 29822: Expected 5 fields in line 29822, saw 9
# Skipping line 29823: Expected 5 fields in line 29823, saw 9
# Skipping line 29826: Expected 5 fields in line 29826, saw 9
# Skipping line 29827: Expected 5 fields in line 29827, saw 6
# Skipping line 29828: Expected 5 fields in line 29828, saw 9
# Skipping line 29829: Expected 5 fields in line 29829, saw 22
# Skipping line 29830: Expected 5 fields in line 29830, saw 23
# Skipping line 29831: Expected 5 fields in line 29831, saw 7
# Skipping line 29833: Expected 5 fields in line 29833, saw 24
# Skipping line 29834: Expected 5 fields in line 29834, saw 8
# Skipping line 29836: Expected 5 fields in line 29836, saw 21
# Skipping line 29838: Expected 5 fields in line 29838, saw 17
# Skipping line 29841: Expected 5 fields in line 29841, saw 36
# Skipping line 29842: Expected 5 fields in line 29842, saw 9
# Skipping line 29843: Expected 5 fields in line 29843, saw 9
# Skipping line 29847: Expected 5 fields in line 29847, saw 14
# Skipping line 29848: Expected 5 fields in line 29848, saw 46
# Skipping line 29850: Expected 5 fields in line 29850, saw 69
# Skipping line 29851: Expected 5 fields in line 29851, saw 18
# Skipping line 29852: Expected 5 fields in line 29852, saw 9
# Skipping line 29855: Expected 5 fields in line 29855, saw 23
# Skipping line 29857: Expected 5 fields in line 29857, saw 38
# Skipping line 29858: Expected 5 fields in line 29858, saw 11
# Skipping line 29859: Expected 5 fields in line 29859, saw 13
# Skipping line 29862: Expected 5 fields in line 29862, saw 23
# Skipping line 29863: Expected 5 fields in line 29863, saw 32
# Skipping line 29866: Expected 5 fields in line 29866, saw 40
# Skipping line 29867: Expected 5 fields in line 29867, saw 34
# Skipping line 29868: Expected 5 fields in line 29868, saw 9
# Skipping line 29870: Expected 5 fields in line 29870, saw 18
# Skipping line 29872: Expected 5 fields in line 29872, saw 30
# Skipping line 29873: Expected 5 fields in line 29873, saw 11
# Skipping line 29875: Expected 5 fields in line 29875, saw 9
# Skipping line 29877: Expected 5 fields in line 29877, saw 18
# Skipping line 29879: Expected 5 fields in line 29879, saw 9
# Skipping line 29881: Expected 5 fields in line 29881, saw 11
# Skipping line 29883: Expected 5 fields in line 29883, saw 38
# Skipping line 29884: Expected 5 fields in line 29884, saw 7
# Skipping line 29886: Expected 5 fields in line 29886, saw 14
# Skipping line 29887: Expected 5 fields in line 29887, saw 9
# Skipping line 29891: Expected 5 fields in line 29891, saw 25
# Skipping line 29892: Expected 5 fields in line 29892, saw 24
# Skipping line 29894: Expected 5 fields in line 29894, saw 6
# Skipping line 29896: Expected 5 fields in line 29896, saw 33
# Skipping line 29897: Expected 5 fields in line 29897, saw 10
# Skipping line 29898: Expected 5 fields in line 29898, saw 9
# Skipping line 29899: Expected 5 fields in line 29899, saw 9
# Skipping line 29902: Expected 5 fields in line 29902, saw 24
# Skipping line 29904: Expected 5 fields in line 29904, saw 27
# Skipping line 29905: Expected 5 fields in line 29905, saw 13
# Skipping line 29906: Expected 5 fields in line 29906, saw 19
# Skipping line 29908: Expected 5 fields in line 29908, saw 12
# Skipping line 29909: Expected 5 fields in line 29909, saw 8
# Skipping line 29910: Expected 5 fields in line 29910, saw 9
# Skipping line 29913: Expected 5 fields in line 29913, saw 31
# Skipping line 29915: Expected 5 fields in line 29915, saw 28
# Skipping line 29916: Expected 5 fields in line 29916, saw 36
# Skipping line 29917: Expected 5 fields in line 29917, saw 9
# Skipping line 29920: Expected 5 fields in line 29920, saw 7
# Skipping line 29922: Expected 5 fields in line 29922, saw 23
# Skipping line 29923: Expected 5 fields in line 29923, saw 21
# Skipping line 29924: Expected 5 fields in line 29924, saw 33
# Skipping line 29926: Expected 5 fields in line 29926, saw 21
# Skipping line 29927: Expected 5 fields in line 29927, saw 7
# Skipping line 29929: Expected 5 fields in line 29929, saw 30
# Skipping line 29931: Expected 5 fields in line 29931, saw 18
# Skipping line 29934: Expected 5 fields in line 29934, saw 32
# Skipping line 29935: Expected 5 fields in line 29935, saw 9
# Skipping line 29938: Expected 5 fields in line 29938, saw 27
# Skipping line 29939: Expected 5 fields in line 29939, saw 17
# Skipping line 29942: Expected 5 fields in line 29942, saw 12
# Skipping line 29943: Expected 5 fields in line 29943, saw 19
# Skipping line 29944: Expected 5 fields in line 29944, saw 9
# Skipping line 29947: Expected 5 fields in line 29947, saw 7
# Skipping line 29948: Expected 5 fields in line 29948, saw 30
# Skipping line 29949: Expected 5 fields in line 29949, saw 23
# Skipping line 29951: Expected 5 fields in line 29951, saw 13
# Skipping line 29953: Expected 5 fields in line 29953, saw 22
# Skipping line 29954: Expected 5 fields in line 29954, saw 25
# Skipping line 29955: Expected 5 fields in line 29955, saw 9
# Skipping line 29957: Expected 5 fields in line 29957, saw 20
# Skipping line 29959: Expected 5 fields in line 29959, saw 17
# Skipping line 29960: Expected 5 fields in line 29960, saw 8
# Skipping line 29962: Expected 5 fields in line 29962, saw 23
# Skipping line 29964: Expected 5 fields in line 29964, saw 19
# Skipping line 29965: Expected 5 fields in line 29965, saw 9
# Skipping line 29967: Expected 5 fields in line 29967, saw 7
# Skipping line 29968: Expected 5 fields in line 29968, saw 28
# Skipping line 29971: Expected 5 fields in line 29971, saw 25
# Skipping line 29972: Expected 5 fields in line 29972, saw 19
# Skipping line 29973: Expected 5 fields in line 29973, saw 9
# Skipping line 29975: Expected 5 fields in line 29975, saw 7
# Skipping line 29977: Expected 5 fields in line 29977, saw 29
# Skipping line 29978: Expected 5 fields in line 29978, saw 16
# Skipping line 29980: Expected 5 fields in line 29980, saw 9
# Skipping line 29982: Expected 5 fields in line 29982, saw 13
# Skipping line 29983: Expected 5 fields in line 29983, saw 10
# Skipping line 29984: Expected 5 fields in line 29984, saw 9
# Skipping line 29985: Expected 5 fields in line 29985, saw 9
# Skipping line 29988: Expected 5 fields in line 29988, saw 37
# Skipping line 29990: Expected 5 fields in line 29990, saw 28
# Skipping line 29991: Expected 5 fields in line 29991, saw 6
# Skipping line 29992: Expected 5 fields in line 29992, saw 38
# Skipping line 29994: Expected 5 fields in line 29994, saw 9
# Skipping line 29995: Expected 5 fields in line 29995, saw 9
# Skipping line 29997: Expected 5 fields in line 29997, saw 22
# Skipping line 30000: Expected 5 fields in line 30000, saw 34
# Skipping line 30002: Expected 5 fields in line 30002, saw 20
# Skipping line 30003: Expected 5 fields in line 30003, saw 40
# Skipping line 30005: Expected 5 fields in line 30005, saw 8
# Skipping line 30008: Expected 5 fields in line 30008, saw 53
# Skipping line 30011: Expected 5 fields in line 30011, saw 21
# Skipping line 30013: Expected 5 fields in line 30013, saw 16
# Skipping line 30014: Expected 5 fields in line 30014, saw 12
# Skipping line 30015: Expected 5 fields in line 30015, saw 9
# Skipping line 30016: Expected 5 fields in line 30016, saw 9
# Skipping line 30019: Expected 5 fields in line 30019, saw 33
# Skipping line 30020: Expected 5 fields in line 30020, saw 9
# Skipping line 30021: Expected 5 fields in line 30021, saw 20
# Skipping line 30022: Expected 5 fields in line 30022, saw 6
# Skipping line 30023: Expected 5 fields in line 30023, saw 64
# Skipping line 30024: Expected 5 fields in line 30024, saw 6
# Skipping line 30025: Expected 5 fields in line 30025, saw 9
# Skipping line 30027: Expected 5 fields in line 30027, saw 18
# Skipping line 30028: Expected 5 fields in line 30028, saw 20
# Skipping line 30030: Expected 5 fields in line 30030, saw 10
# Skipping line 30032: Expected 5 fields in line 30032, saw 21
# Skipping line 30033: Expected 5 fields in line 30033, saw 22
# Skipping line 30034: Expected 5 fields in line 30034, saw 9
# Skipping line 30036: Expected 5 fields in line 30036, saw 8
# Skipping line 30038: Expected 5 fields in line 30038, saw 15
# Skipping line 30039: Expected 5 fields in line 30039, saw 42
# Skipping line 30041: Expected 5 fields in line 30041, saw 30
# Skipping line 30043: Expected 5 fields in line 30043, saw 12
# Skipping line 30044: Expected 5 fields in line 30044, saw 7
# Skipping line 30045: Expected 5 fields in line 30045, saw 9
# Skipping line 30047: Expected 5 fields in line 30047, saw 14
# Skipping line 30049: Expected 5 fields in line 30049, saw 61
# Skipping line 30051: Expected 5 fields in line 30051, saw 34
# Skipping line 30052: Expected 5 fields in line 30052, saw 27
# Skipping line 30053: Expected 5 fields in line 30053, saw 9
# Skipping line 30055: Expected 5 fields in line 30055, saw 12
# Skipping line 30057: Expected 5 fields in line 30057, saw 26
# Skipping line 30058: Expected 5 fields in line 30058, saw 15
# Skipping line 30060: Expected 5 fields in line 30060, saw 8
# Skipping line 30062: Expected 5 fields in line 30062, saw 12
# Skipping line 30063: Expected 5 fields in line 30063, saw 24
# Skipping line 30064: Expected 5 fields in line 30064, saw 9
# Skipping line 30066: Expected 5 fields in line 30066, saw 34
# Skipping line 30068: Expected 5 fields in line 30068, saw 12
# Skipping line 30069: Expected 5 fields in line 30069, saw 9
# Skipping line 30074: Expected 5 fields in line 30074, saw 31
# Skipping line 30075: Expected 5 fields in line 30075, saw 6
# Skipping line 30079: Expected 5 fields in line 30079, saw 20
# Skipping line 30080: Expected 5 fields in line 30080, saw 9
# Skipping line 30084: Expected 5 fields in line 30084, saw 14
# Skipping line 30085: Expected 5 fields in line 30085, saw 9
# Skipping line 30086: Expected 5 fields in line 30086, saw 25
# Skipping line 30087: Expected 5 fields in line 30087, saw 11
# Skipping line 30090: Expected 5 fields in line 30090, saw 6
# Skipping line 30091: Expected 5 fields in line 30091, saw 11
# Skipping line 30092: Expected 5 fields in line 30092, saw 8
# Skipping line 30095: Expected 5 fields in line 30095, saw 10
# Skipping line 30096: Expected 5 fields in line 30096, saw 7
# Skipping line 30099: Expected 5 fields in line 30099, saw 12
# Skipping line 30100: Expected 5 fields in line 30100, saw 9
# Skipping line 30102: Expected 5 fields in line 30102, saw 20
# Skipping line 30103: Expected 5 fields in line 30103, saw 18
# Skipping line 30108: Expected 5 fields in line 30108, saw 17
# Skipping line 30110: Expected 5 fields in line 30110, saw 6
# Skipping line 30115: Expected 5 fields in line 30115, saw 21
# Skipping line 30117: Expected 5 fields in line 30117, saw 6
# Skipping line 30119: Expected 5 fields in line 30119, saw 7
# Skipping line 30120: Expected 5 fields in line 30120, saw 11
# Skipping line 30123: Expected 5 fields in line 30123, saw 6
# Skipping line 30125: Expected 5 fields in line 30125, saw 10
# Skipping line 30126: Expected 5 fields in line 30126, saw 22
# Skipping line 30127: Expected 5 fields in line 30127, saw 15
# Skipping line 30130: Expected 5 fields in line 30130, saw 14
# Skipping line 30131: Expected 5 fields in line 30131, saw 10
# Skipping line 30132: Expected 5 fields in line 30132, saw 21
# Skipping line 30133: Expected 5 fields in line 30133, saw 15
# Skipping line 30136: Expected 5 fields in line 30136, saw 24
# Skipping line 30138: Expected 5 fields in line 30138, saw 11
# Skipping line 30139: Expected 5 fields in line 30139, saw 9
# Skipping line 30140: Expected 5 fields in line 30140, saw 10
# Skipping line 30143: Expected 5 fields in line 30143, saw 7
# Skipping line 30144: Expected 5 fields in line 30144, saw 18
# Skipping line 30145: Expected 5 fields in line 30145, saw 17
# Skipping line 30146: Expected 5 fields in line 30146, saw 10
# Skipping line 30147: Expected 5 fields in line 30147, saw 10
# Skipping line 30150: Expected 5 fields in line 30150, saw 9
# Skipping line 30151: Expected 5 fields in line 30151, saw 12
# Skipping line 30152: Expected 5 fields in line 30152, saw 10
# Skipping line 30153: Expected 5 fields in line 30153, saw 15
# Skipping line 30156: Expected 5 fields in line 30156, saw 6
# Skipping line 30157: Expected 5 fields in line 30157, saw 16
# Skipping line 30158: Expected 5 fields in line 30158, saw 6
# Skipping line 30169: Expected 5 fields in line 30169, saw 7
# Skipping line 30171: Expected 5 fields in line 30171, saw 7
# Skipping line 30173: Expected 5 fields in line 30173, saw 31
# Skipping line 30177: Expected 5 fields in line 30177, saw 8
# Skipping line 30179: Expected 5 fields in line 30179, saw 8
# Skipping line 30180: Expected 5 fields in line 30180, saw 8
# Skipping line 30181: Expected 5 fields in line 30181, saw 9
# Skipping line 30182: Expected 5 fields in line 30182, saw 8
# Skipping line 30183: Expected 5 fields in line 30183, saw 8
# Skipping line 30184: Expected 5 fields in line 30184, saw 8
# Skipping line 30185: Expected 5 fields in line 30185, saw 8
# Skipping line 30186: Expected 5 fields in line 30186, saw 10
# Skipping line 30187: Expected 5 fields in line 30187, saw 10
# Skipping line 30190: Expected 5 fields in line 30190, saw 8
# Skipping line 30191: Expected 5 fields in line 30191, saw 6
# Skipping line 30192: Expected 5 fields in line 30192, saw 8
# Skipping line 30193: Expected 5 fields in line 30193, saw 6
# Skipping line 30194: Expected 5 fields in line 30194, saw 6
# Skipping line 30195: Expected 5 fields in line 30195, saw 7
# Skipping line 30196: Expected 5 fields in line 30196, saw 9
# Skipping line 30197: Expected 5 fields in line 30197, saw 6
# Skipping line 30198: Expected 5 fields in line 30198, saw 8
# Skipping line 30199: Expected 5 fields in line 30199, saw 8
# Skipping line 30200: Expected 5 fields in line 30200, saw 8
# Skipping line 30201: Expected 5 fields in line 30201, saw 8
# Skipping line 30204: Expected 5 fields in line 30204, saw 8
# Skipping line 30205: Expected 5 fields in line 30205, saw 8
# Skipping line 30206: Expected 5 fields in line 30206, saw 8
# Skipping line 30207: Expected 5 fields in line 30207, saw 7
# Skipping line 30208: Expected 5 fields in line 30208, saw 6
# Skipping line 30209: Expected 5 fields in line 30209, saw 11
# Skipping line 30210: Expected 5 fields in line 30210, saw 8
# Skipping line 30211: Expected 5 fields in line 30211, saw 8
# Skipping line 30212: Expected 5 fields in line 30212, saw 6
# Skipping line 30213: Expected 5 fields in line 30213, saw 6
# Skipping line 30214: Expected 5 fields in line 30214, saw 10
# Skipping line 30217: Expected 5 fields in line 30217, saw 7
# Skipping line 30218: Expected 5 fields in line 30218, saw 8
# Skipping line 30219: Expected 5 fields in line 30219, saw 8
# Skipping line 30220: Expected 5 fields in line 30220, saw 23
# Skipping line 30223: Expected 5 fields in line 30223, saw 10
# Skipping line 30224: Expected 5 fields in line 30224, saw 6
# Skipping line 30225: Expected 5 fields in line 30225, saw 6
# Skipping line 30226: Expected 5 fields in line 30226, saw 8
# Skipping line 30227: Expected 5 fields in line 30227, saw 8
# Skipping line 30228: Expected 5 fields in line 30228, saw 8
# Skipping line 30229: Expected 5 fields in line 30229, saw 8
# Skipping line 30230: Expected 5 fields in line 30230, saw 7
# Skipping line 30231: Expected 5 fields in line 30231, saw 8
# Skipping line 30232: Expected 5 fields in line 30232, saw 8
# Skipping line 30233: Expected 5 fields in line 30233, saw 8
# Skipping line 30236: Expected 5 fields in line 30236, saw 8
# Skipping line 30239: Expected 5 fields in line 30239, saw 6
# Skipping line 30287: Expected 5 fields in line 30287, saw 6
# Skipping line 30290: Expected 5 fields in line 30290, saw 6
# Skipping line 30413: Expected 5 fields in line 30413, saw 10
# Skipping line 30414: Expected 5 fields in line 30414, saw 9
# Skipping line 30415: Expected 5 fields in line 30415, saw 7
# Skipping line 30418: Expected 5 fields in line 30418, saw 6
# Skipping line 30460: Expected 5 fields in line 30460, saw 6
# Skipping line 30464: Expected 5 fields in line 30464, saw 6
# Skipping line 30529: Expected 5 fields in line 30529, saw 9
# Skipping line 30530: Expected 5 fields in line 30530, saw 9
# Skipping line 30533: Expected 5 fields in line 30533, saw 6
# Skipping line 30555: Expected 5 fields in line 30555, saw 6
# Skipping line 30564: Expected 5 fields in line 30564, saw 6
# Skipping line 30578: Expected 5 fields in line 30578, saw 7
# Skipping line 30627: Expected 5 fields in line 30627, saw 13
# Skipping line 30628: Expected 5 fields in line 30628, saw 11
# Skipping line 30629: Expected 5 fields in line 30629, saw 10
# Skipping line 30630: Expected 5 fields in line 30630, saw 10
# Skipping line 30631: Expected 5 fields in line 30631, saw 10
# Skipping line 30632: Expected 5 fields in line 30632, saw 7
# Skipping line 30633: Expected 5 fields in line 30633, saw 6
# Skipping line 30637: Expected 5 fields in line 30637, saw 8
# Skipping line 30638: Expected 5 fields in line 30638, saw 6
# Skipping line 30640: Expected 5 fields in line 30640, saw 6
# Skipping line 30649: Expected 5 fields in line 30649, saw 6
# Skipping line 30663: Expected 5 fields in line 30663, saw 14
# Skipping line 30680: Expected 5 fields in line 30680, saw 8
# Skipping line 30683: Expected 5 fields in line 30683, saw 9
# Skipping line 30684: Expected 5 fields in line 30684, saw 8
# Skipping line 30685: Expected 5 fields in line 30685, saw 10
# Skipping line 30686: Expected 5 fields in line 30686, saw 10
# Skipping line 30695: Expected 5 fields in line 30695, saw 11
# Skipping line 30696: Expected 5 fields in line 30696, saw 9
# Skipping line 30698: Expected 5 fields in line 30698, saw 21
# Skipping line 30700: Expected 5 fields in line 30700, saw 11
# Skipping line 30701: Expected 5 fields in line 30701, saw 11
# Skipping line 30702: Expected 5 fields in line 30702, saw 10
# Skipping line 30706: Expected 5 fields in line 30706, saw 6
# Skipping line 30707: Expected 5 fields in line 30707, saw 15
# Skipping line 30710: Expected 5 fields in line 30710, saw 12
# Skipping line 30711: Expected 5 fields in line 30711, saw 6
# Skipping line 30713: Expected 5 fields in line 30713, saw 12
# Skipping line 30714: Expected 5 fields in line 30714, saw 8
# Skipping line 30715: Expected 5 fields in line 30715, saw 10
# Skipping line 30717: Expected 5 fields in line 30717, saw 15
# Skipping line 30718: Expected 5 fields in line 30718, saw 12
# Skipping line 30719: Expected 5 fields in line 30719, saw 10
# Skipping line 30720: Expected 5 fields in line 30720, saw 6
# Skipping line 30723: Expected 5 fields in line 30723, saw 6
# Skipping line 30725: Expected 5 fields in line 30725, saw 6
# Skipping line 30730: Expected 5 fields in line 30730, saw 6
# Skipping line 30733: Expected 5 fields in line 30733, saw 6
# Skipping line 30739: Expected 5 fields in line 30739, saw 6
# Skipping line 30740: Expected 5 fields in line 30740, saw 6
# Skipping line 30743: Expected 5 fields in line 30743, saw 6
# Skipping line 30744: Expected 5 fields in line 30744, saw 6
# Skipping line 30745: Expected 5 fields in line 30745, saw 6
# Skipping line 30747: Expected 5 fields in line 30747, saw 6
# Skipping line 30748: Expected 5 fields in line 30748, saw 6
# Skipping line 30750: Expected 5 fields in line 30750, saw 6
# Skipping line 30751: Expected 5 fields in line 30751, saw 6
# Skipping line 30755: Expected 5 fields in line 30755, saw 6
# Skipping line 30758: Expected 5 fields in line 30758, saw 6
# Skipping line 30759: Expected 5 fields in line 30759, saw 6
# Skipping line 30761: Expected 5 fields in line 30761, saw 6
# Skipping line 30762: Expected 5 fields in line 30762, saw 12
# Skipping line 30763: Expected 5 fields in line 30763, saw 20
# Skipping line 30769: Expected 5 fields in line 30769, saw 8
# Skipping line 30770: Expected 5 fields in line 30770, saw 7
# Skipping line 30777: Expected 5 fields in line 30777, saw 14
# Skipping line 30778: Expected 5 fields in line 30778, saw 8
# Skipping line 30779: Expected 5 fields in line 30779, saw 11
# Skipping line 30782: Expected 5 fields in line 30782, saw 6
# Skipping line 30783: Expected 5 fields in line 30783, saw 10
# Skipping line 30785: Expected 5 fields in line 30785, saw 8
# Skipping line 30786: Expected 5 fields in line 30786, saw 13
# Skipping line 30787: Expected 5 fields in line 30787, saw 8
# Skipping line 30788: Expected 5 fields in line 30788, saw 10
# Skipping line 30789: Expected 5 fields in line 30789, saw 9
# Skipping line 30790: Expected 5 fields in line 30790, saw 10
# Skipping line 30791: Expected 5 fields in line 30791, saw 11
# Skipping line 30793: Expected 5 fields in line 30793, saw 10
# Skipping line 30798: Expected 5 fields in line 30798, saw 12
# Skipping line 30802: Expected 5 fields in line 30802, saw 14
# Skipping line 30803: Expected 5 fields in line 30803, saw 7
# Skipping line 30805: Expected 5 fields in line 30805, saw 12
# Skipping line 30806: Expected 5 fields in line 30806, saw 11
# Skipping line 30807: Expected 5 fields in line 30807, saw 13
# Skipping line 30808: Expected 5 fields in line 30808, saw 6
# Skipping line 30810: Expected 5 fields in line 30810, saw 6
# Skipping line 30811: Expected 5 fields in line 30811, saw 6
# Skipping line 30812: Expected 5 fields in line 30812, saw 11
# Skipping line 30813: Expected 5 fields in line 30813, saw 11
# Skipping line 30814: Expected 5 fields in line 30814, saw 7
# Skipping line 30815: Expected 5 fields in line 30815, saw 12
# Skipping line 30816: Expected 5 fields in line 30816, saw 7
# Skipping line 30817: Expected 5 fields in line 30817, saw 6
# Skipping line 30818: Expected 5 fields in line 30818, saw 11
# Skipping line 30819: Expected 5 fields in line 30819, saw 12
# Skipping line 30820: Expected 5 fields in line 30820, saw 13
# Skipping line 30822: Expected 5 fields in line 30822, saw 6
# Skipping line 30823: Expected 5 fields in line 30823, saw 12
# Skipping line 30830: Expected 5 fields in line 30830, saw 7
# Skipping line 30832: Expected 5 fields in line 30832, saw 9
# Skipping line 30833: Expected 5 fields in line 30833, saw 10
# Skipping line 30834: Expected 5 fields in line 30834, saw 11
# Skipping line 30835: Expected 5 fields in line 30835, saw 10
# Skipping line 30836: Expected 5 fields in line 30836, saw 9
# Skipping line 30839: Expected 5 fields in line 30839, saw 8
# Skipping line 30840: Expected 5 fields in line 30840, saw 8
# Skipping line 30842: Expected 5 fields in line 30842, saw 9
# Skipping line 30846: Expected 5 fields in line 30846, saw 7
# Skipping line 30850: Expected 5 fields in line 30850, saw 6
# Skipping line 30851: Expected 5 fields in line 30851, saw 7
# Skipping line 30853: Expected 5 fields in line 30853, saw 6
# Skipping line 30858: Expected 5 fields in line 30858, saw 7
# Skipping line 30860: Expected 5 fields in line 30860, saw 17
# Skipping line 30864: Expected 5 fields in line 30864, saw 6
# Skipping line 30868: Expected 5 fields in line 30868, saw 7
# Skipping line 30870: Expected 5 fields in line 30870, saw 7
# Skipping line 30887: Expected 5 fields in line 30887, saw 6
# Skipping line 30889: Expected 5 fields in line 30889, saw 6
# Skipping line 30902: Expected 5 fields in line 30902, saw 7
# ...
# Skipping line 15626: Expected 5 fields in line 15626, saw 6
# Skipping line 15627: Expected 5 fields in line 15627, saw 6
# Skipping line 15628: Expected 5 fields in line 15628, saw 8
# Skipping line 15631: Expected 5 fields in line 15631, saw 7
# Skipping line 15635: Expected 5 fields in line 15635, saw 9
# Skipping line 15642: Expected 5 fields in line 15642, saw 6
# Skipping line 15643: Expected 5 fields in line 15643, saw 15
# Skipping line 15644: Expected 5 fields in line 15644, saw 15
# Skipping line 15646: Expected 5 fields in line 15646, saw 7
# Skipping line 15647: Expected 5 fields in line 15647, saw 8
# Skipping line 15651: Expected 5 fields in line 15651, saw 17
# Skipping line 15652: Expected 5 fields in line 15652, saw 7
# Skipping line 15653: Expected 5 fields in line 15653, saw 15
# Skipping line 15654: Expected 5 fields in line 15654, saw 11
# Skipping line 15655: Expected 5 fields in line 15655, saw 10
# Skipping line 15659: Expected 5 fields in line 15659, saw 9
# Skipping line 15660: Expected 5 fields in line 15660, saw 7
# Skipping line 15661: Expected 5 fields in line 15661, saw 11
# Skipping line 15665: Expected 5 fields in line 15665, saw 7
# Skipping line 15678: Expected 5 fields in line 15678, saw 20
# Skipping line 15679: Expected 5 fields in line 15679, saw 16
# Skipping line 15683: Expected 5 fields in line 15683, saw 14
# Skipping line 15684: Expected 5 fields in line 15684, saw 10
# Skipping line 15685: Expected 5 fields in line 15685, saw 6
# Skipping line 15687: Expected 5 fields in line 15687, saw 7
# Skipping line 15689: Expected 5 fields in line 15689, saw 6
# Skipping line 15691: Expected 5 fields in line 15691, saw 10
# Skipping line 15693: Expected 5 fields in line 15693, saw 7
# Skipping line 15694: Expected 5 fields in line 15694, saw 6
# Skipping line 15695: Expected 5 fields in line 15695, saw 6
# Skipping line 15696: Expected 5 fields in line 15696, saw 9
# Skipping line 15697: Expected 5 fields in line 15697, saw 13
# Skipping line 15698: Expected 5 fields in line 15698, saw 7
# Skipping line 15702: Expected 5 fields in line 15702, saw 9
# Skipping line 15703: Expected 5 fields in line 15703, saw 11
# Skipping line 15705: Expected 5 fields in line 15705, saw 11
# Skipping line 15706: Expected 5 fields in line 15706, saw 9
# Skipping line 15710: Expected 5 fields in line 15710, saw 8
# Skipping line 15711: Expected 5 fields in line 15711, saw 9
# Skipping line 15712: Expected 5 fields in line 15712, saw 12
# Skipping line 15714: Expected 5 fields in line 15714, saw 9
# Skipping line 15715: Expected 5 fields in line 15715, saw 13
# Skipping line 15716: Expected 5 fields in line 15716, saw 7
# Skipping line 15717: Expected 5 fields in line 15717, saw 9
# Skipping line 15718: Expected 5 fields in line 15718, saw 11
# Skipping line 15729: Expected 5 fields in line 15729, saw 6
# Skipping line 15730: Expected 5 fields in line 15730, saw 10
# Skipping line 15731: Expected 5 fields in line 15731, saw 15
# Skipping line 15732: Expected 5 fields in line 15732, saw 6
# Skipping line 15733: Expected 5 fields in line 15733, saw 11
# Skipping line 15737: Expected 5 fields in line 15737, saw 8
# Skipping line 15738: Expected 5 fields in line 15738, saw 8
# Skipping line 15739: Expected 5 fields in line 15739, saw 9
# Skipping line 15740: Expected 5 fields in line 15740, saw 9
# Skipping line 15741: Expected 5 fields in line 15741, saw 10
# Skipping line 15742: Expected 5 fields in line 15742, saw 13
# Skipping line 15743: Expected 5 fields in line 15743, saw 22
# Skipping line 15748: Expected 5 fields in line 15748, saw 19
# Skipping line 15749: Expected 5 fields in line 15749, saw 7
# Skipping line 15750: Expected 5 fields in line 15750, saw 6
# Skipping line 15752: Expected 5 fields in line 15752, saw 19
# Skipping line 15757: Expected 5 fields in line 15757, saw 7
# Skipping line 15759: Expected 5 fields in line 15759, saw 47
# Skipping line 15760: Expected 5 fields in line 15760, saw 9
# Skipping line 15761: Expected 5 fields in line 15761, saw 9
# Skipping line 15765: Expected 5 fields in line 15765, saw 6
# Skipping line 15766: Expected 5 fields in line 15766, saw 10
# Skipping line 15767: Expected 5 fields in line 15767, saw 14
# Skipping line 15768: Expected 5 fields in line 15768, saw 8
# Skipping line 15769: Expected 5 fields in line 15769, saw 18
# Skipping line 15774: Expected 5 fields in line 15774, saw 10
# Skipping line 15775: Expected 5 fields in line 15775, saw 10
# Skipping line 15776: Expected 5 fields in line 15776, saw 6
# Skipping line 15778: Expected 5 fields in line 15778, saw 8
# Skipping line 15779: Expected 5 fields in line 15779, saw 11
# Skipping line 15791: Expected 5 fields in line 15791, saw 12
# Skipping line 15792: Expected 5 fields in line 15792, saw 9
# Skipping line 15793: Expected 5 fields in line 15793, saw 7
# Skipping line 15797: Expected 5 fields in line 15797, saw 15
# Skipping line 15798: Expected 5 fields in line 15798, saw 13
# Skipping line 15799: Expected 5 fields in line 15799, saw 14
# Skipping line 15800: Expected 5 fields in line 15800, saw 105
# Skipping line 15806: Expected 5 fields in line 15806, saw 11
# Skipping line 15807: Expected 5 fields in line 15807, saw 13
# Skipping line 15809: Expected 5 fields in line 15809, saw 20
# Skipping line 15810: Expected 5 fields in line 15810, saw 20
# Skipping line 15825: Expected 5 fields in line 15825, saw 11
# Skipping line 15826: Expected 5 fields in line 15826, saw 6
# Skipping line 15828: Expected 5 fields in line 15828, saw 9
# Skipping line 15829: Expected 5 fields in line 15829, saw 14
# Skipping line 15835: Expected 5 fields in line 15835, saw 9
# Skipping line 15836: Expected 5 fields in line 15836, saw 11
# Skipping line 15837: Expected 5 fields in line 15837, saw 20
# Skipping line 15838: Expected 5 fields in line 15838, saw 10
# Skipping line 15839: Expected 5 fields in line 15839, saw 8
# Skipping line 15844: Expected 5 fields in line 15844, saw 44
# Skipping line 15846: Expected 5 fields in line 15846, saw 12
# Skipping line 15847: Expected 5 fields in line 15847, saw 7
# Skipping line 15848: Expected 5 fields in line 15848, saw 29
# Skipping line 15849: Expected 5 fields in line 15849, saw 15
# Skipping line 15850: Expected 5 fields in line 15850, saw 6
# Skipping line 15852: Expected 5 fields in line 15852, saw 7
# Skipping line 15856: Expected 5 fields in line 15856, saw 10
# Skipping line 15858: Expected 5 fields in line 15858, saw 9
# Skipping line 15867: Expected 5 fields in line 15867, saw 7
# Skipping line 15869: Expected 5 fields in line 15869, saw 6
# Skipping line 15887: Expected 5 fields in line 15887, saw 8
# Skipping line 15930: Expected 5 fields in line 15930, saw 7
# Skipping line 15945: Expected 5 fields in line 15945, saw 7
# Skipping line 15948: Expected 5 fields in line 15948, saw 6
# Skipping line 15949: Expected 5 fields in line 15949, saw 6
# Skipping line 15973: Expected 5 fields in line 15973, saw 22
# Skipping line 15975: Expected 5 fields in line 15975, saw 12
# Skipping line 15976: Expected 5 fields in line 15976, saw 6
# Skipping line 15977: Expected 5 fields in line 15977, saw 10
# Skipping line 15978: Expected 5 fields in line 15978, saw 12
# Skipping line 15980: Expected 5 fields in line 15980, saw 16
# Skipping line 15982: Expected 5 fields in line 15982, saw 16
# Skipping line 15984: Expected 5 fields in line 15984, saw 6
# Skipping line 15986: Expected 5 fields in line 15986, saw 6
# Skipping line 15989: Expected 5 fields in line 15989, saw 7
# Skipping line 15992: Expected 5 fields in line 15992, saw 10
# Skipping line 16073: Expected 5 fields in line 16073, saw 7
# Skipping line 16074: Expected 5 fields in line 16074, saw 20
# Skipping line 16075: Expected 5 fields in line 16075, saw 9
# Skipping line 16076: Expected 5 fields in line 16076, saw 6
# Skipping line 16077: Expected 5 fields in line 16077, saw 7
# Skipping line 16078: Expected 5 fields in line 16078, saw 7
# Skipping line 16079: Expected 5 fields in line 16079, saw 7
# Skipping line 16080: Expected 5 fields in line 16080, saw 9
# Skipping line 16082: Expected 5 fields in line 16082, saw 6
# Skipping line 16083: Expected 5 fields in line 16083, saw 6
# Skipping line 16084: Expected 5 fields in line 16084, saw 6
# Skipping line 16089: Expected 5 fields in line 16089, saw 17
# Skipping line 16090: Expected 5 fields in line 16090, saw 11
# Skipping line 16096: Expected 5 fields in line 16096, saw 8
# Skipping line 16097: Expected 5 fields in line 16097, saw 11
# Skipping line 16105: Expected 5 fields in line 16105, saw 11
# Skipping line 16106: Expected 5 fields in line 16106, saw 7
# Skipping line 16109: Expected 5 fields in line 16109, saw 6
# Skipping line 16110: Expected 5 fields in line 16110, saw 6
# Skipping line 16116: Expected 5 fields in line 16116, saw 6
# Skipping line 16122: Expected 5 fields in line 16122, saw 6
# Skipping line 16134: Expected 5 fields in line 16134, saw 6
# Skipping line 16137: Expected 5 fields in line 16137, saw 12
# Skipping line 16138: Expected 5 fields in line 16138, saw 13
# Skipping line 16145: Expected 5 fields in line 16145, saw 11
# Skipping line 16147: Expected 5 fields in line 16147, saw 15
# Skipping line 16158: Expected 5 fields in line 16158, saw 8
# Skipping line 16159: Expected 5 fields in line 16159, saw 15
# Skipping line 16160: Expected 5 fields in line 16160, saw 7
# Skipping line 16161: Expected 5 fields in line 16161, saw 10
# Skipping line 16162: Expected 5 fields in line 16162, saw 8
# Skipping line 16163: Expected 5 fields in line 16163, saw 11
# Skipping line 16164: Expected 5 fields in line 16164, saw 9
# Skipping line 16165: Expected 5 fields in line 16165, saw 15
# Skipping line 16166: Expected 5 fields in line 16166, saw 10
# Skipping line 16167: Expected 5 fields in line 16167, saw 7
# Skipping line 16168: Expected 5 fields in line 16168, saw 7
# Skipping line 16169: Expected 5 fields in line 16169, saw 11
# Skipping line 16170: Expected 5 fields in line 16170, saw 7
# Skipping line 16171: Expected 5 fields in line 16171, saw 7
# Skipping line 16172: Expected 5 fields in line 16172, saw 14
# Skipping line 16173: Expected 5 fields in line 16173, saw 13
# Skipping line 16174: Expected 5 fields in line 16174, saw 14
# Skipping line 16175: Expected 5 fields in line 16175, saw 8
# Skipping line 16176: Expected 5 fields in line 16176, saw 9
# Skipping line 16177: Expected 5 fields in line 16177, saw 15
# Skipping line 16178: Expected 5 fields in line 16178, saw 13
# Skipping line 16179: Expected 5 fields in line 16179, saw 12
# Skipping line 16180: Expected 5 fields in line 16180, saw 10
# Skipping line 16181: Expected 5 fields in line 16181, saw 8
# Skipping line 16182: Expected 5 fields in line 16182, saw 11
# Skipping line 16183: Expected 5 fields in line 16183, saw 11
# Skipping line 16184: Expected 5 fields in line 16184, saw 13
# Skipping line 16185: Expected 5 fields in line 16185, saw 15
# Skipping line 16186: Expected 5 fields in line 16186, saw 8
# Skipping line 16187: Expected 5 fields in line 16187, saw 10
# Skipping line 16188: Expected 5 fields in line 16188, saw 15
# Skipping line 16189: Expected 5 fields in line 16189, saw 9
# Skipping line 16190: Expected 5 fields in line 16190, saw 10
# Skipping line 16195: Expected 5 fields in line 16195, saw 11
# Skipping line 16196: Expected 5 fields in line 16196, saw 9
# Skipping line 16197: Expected 5 fields in line 16197, saw 12
# Skipping line 16198: Expected 5 fields in line 16198, saw 15
# Skipping line 16199: Expected 5 fields in line 16199, saw 8
# Skipping line 16200: Expected 5 fields in line 16200, saw 15
# Skipping line 16201: Expected 5 fields in line 16201, saw 7
# Skipping line 16202: Expected 5 fields in line 16202, saw 8
# Skipping line 16203: Expected 5 fields in line 16203, saw 13
# Skipping line 16204: Expected 5 fields in line 16204, saw 11
# Skipping line 16205: Expected 5 fields in line 16205, saw 13
# Skipping line 16206: Expected 5 fields in line 16206, saw 8
# Skipping line 16207: Expected 5 fields in line 16207, saw 8
# Skipping line 16208: Expected 5 fields in line 16208, saw 15
# Skipping line 16209: Expected 5 fields in line 16209, saw 14
# Skipping line 16210: Expected 5 fields in line 16210, saw 13
# Skipping line 16211: Expected 5 fields in line 16211, saw 10
# Skipping line 16212: Expected 5 fields in line 16212, saw 7
# Skipping line 16213: Expected 5 fields in line 16213, saw 12
# Skipping line 16214: Expected 5 fields in line 16214, saw 8
# Skipping line 16215: Expected 5 fields in line 16215, saw 11
# Skipping line 16216: Expected 5 fields in line 16216, saw 15
# Skipping line 16217: Expected 5 fields in line 16217, saw 8
# Skipping line 16218: Expected 5 fields in line 16218, saw 9
# Skipping line 16219: Expected 5 fields in line 16219, saw 8
# Skipping line 16220: Expected 5 fields in line 16220, saw 8
# Skipping line 16221: Expected 5 fields in line 16221, saw 7
# Skipping line 16226: Expected 5 fields in line 16226, saw 9
# Skipping line 16227: Expected 5 fields in line 16227, saw 14
# Skipping line 16228: Expected 5 fields in line 16228, saw 8
# Skipping line 16229: Expected 5 fields in line 16229, saw 23
# Skipping line 16234: Expected 5 fields in line 16234, saw 13
# Skipping line 16235: Expected 5 fields in line 16235, saw 10
# Skipping line 16236: Expected 5 fields in line 16236, saw 13
# Skipping line 16237: Expected 5 fields in line 16237, saw 6
# Skipping line 16238: Expected 5 fields in line 16238, saw 8
# Skipping line 16239: Expected 5 fields in line 16239, saw 11
# Skipping line 16240: Expected 5 fields in line 16240, saw 9
# Skipping line 16241: Expected 5 fields in line 16241, saw 41
# Skipping line 16243: Expected 5 fields in line 16243, saw 17
# Skipping line 16245: Expected 5 fields in line 16245, saw 36
# Skipping line 16252: Expected 5 fields in line 16252, saw 15
#                                                 sentence  label         data  \
# 0                                       Original Article      0          NaN
# 1                              Medicine General & Policy      0          NaN
# 2      ORCID iDs Youseung Chung https://orcid.org/000...      0          NaN
# 3                      Maternal and Neonatal Outcomes in      0          NaN
# 4                        Pregnant Women With Coronavirus      1  Coronavirus
# ...                                                  ...    ...          ...
# 11924  Publisher's note Springer Nature remains neutr...      0          NaN
# 11925                               © The Author(s) 2022      0          NaN
# 11926  Scientific Data | (2022) 9:654 | https://doi.o...      0          NaN
# 11927                                                 11      0          NaN
# 11928                                                        0          NaN
#
#        regex subset
# 0      False   Test
# 1      False   Test
# 2      False   Test
# 3      False   Test
# 4       True   Test
# ...      ...    ...
# 11924  False   Test
# 11925  False   Test
# 11926  False   Test
# 11927  False   Test
# 11928  False   Test
#
# [11929 rows x 5 columns]
#                                             sentence  label         data  \
# 0                                   Original Article      0          NaN
# 1                          Medicine General & Policy      0          NaN
# 2  ORCID iDs Youseung Chung https://orcid.org/000...      0          NaN
# 3                  Maternal and Neonatal Outcomes in      0          NaN
# 4                    Pregnant Women With Coronavirus      1  Coronavirus
#
#    regex subset
# 0  False   Test
# 1  False   Test
# 2  False   Test
# 3  False   Test
# 4   True   Test
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-e968fd36e5bc3aeb/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-e968fd36e5bc3aeb/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
sentences = train_df.iloc[0:6, 0]
#print(sentences)
sequences = sentences
print(sequences)
corpus = ' '.join(sequences)

'''
corpus = [
    "This is the Hugging Face Course.",
    "This chapter is about tokenization.",
    "This section shows several tokenizer algorithms.",
    "Hopefully, you will be able to understand how they are trained and generate tokens.",
]'''

#context
# Out:
# 2     SARS-CoV-2 Omicron Variant of Concern: Everyth...
# 7                SARS-CoV-2 Omicron Variant of Concern
# 65               SARS-CoV-2 Omicron Variant of Concern
# 70    Table 2. Monoclonal Antibodies for Treatment o...
# 76    02/11/2022 Mild-to-moderate COVID-19 in adults...
# 78    positive results who are at high risk for prog...
# Name: sentence, dtype: object
# '\ncorpus = [\n    "This is the Hugging Face Course.",\n    "This chapter is about tokenization.",\n    "This section shows several tokenizer algorithms.",\n    "Hopefully, you will be able to understand how they are trained and generate tokens.",\n]'

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("xlnet-base-cased")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]

# %%
from collections import defaultdict

word_freqs = defaultdict(int)
for text in corpus:
    words_with_offsets = tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str(text)
    new_words = [word for word, offset in words_with_offsets]
    for word in new_words:
        word_freqs[word] += 1

word_freqs
# Out:
# defaultdict(int,
#             {'▁S': 6,
#              '▁A': 6,
#              '▁R': 3,
#              '▁-': 10,
#              '▁C': 8,
#              '▁o': 33,
#              '▁V': 8,
#              '▁2': 9,
#              '▁O': 6,
#              '▁m': 6,
#              '▁i': 23,
#              '▁c': 9,
#              '▁r': 26,
#              '▁n': 24,
#              '▁a': 20,
#              '▁t': 23,
#              '▁f': 7,
#              '▁e': 22,
#              '▁:': 1,
#              '▁E': 1,
#              '▁v': 3,
#              '▁y': 2,
#              '▁h': 6,
#              '▁g': 4,
#              '▁Y': 1,
#              '▁u': 5,
#              '▁W': 2,
#              '▁d': 8,
#              '▁K': 1,
#              '▁w': 3,
#              '▁b': 4,
#              '▁s': 12,
#              '▁k': 2,
#              '▁T': 2,
#              '▁l': 7,
#              '▁.': 1,
#              '▁M': 2,
#              '▁P': 1,
#              '▁p': 5,
#              '▁x': 1,
#              '▁I': 2,
#              '▁D': 2,
#              '▁1': 4,
#              '▁9': 2,
#              '▁3': 1,
#              '▁0': 2,
#              '▁/': 2})

# %%
char_freqs = defaultdict(int)
subwords_freqs = defaultdict(int)
for word, freq in word_freqs.items():
    for i in range(len(word)):
        char_freqs[word[i]] += freq
        # Loop through the subwords of length at least 2
        for j in range(i + 2, len(word) + 1):
            subwords_freqs[word[i:j]] += freq

# Sort subwords by frequency
sorted_subwords = sorted(subwords_freqs.items(), key=lambda x: x[1], reverse=True)
sorted_subwords[:10]
# Out:
# [('▁o', 33),
#  ('▁r', 26),
#  ('▁n', 24),
#  ('▁i', 23),
#  ('▁t', 23),
#  ('▁e', 22),
#  ('▁a', 20),
#  ('▁s', 12),
#  ('▁-', 10),
#  ('▁2', 9)]

# %%
token_freqs = list(char_freqs.items()) + sorted_subwords[: 300 - len(char_freqs)]
token_freqs = {token: freq for token, freq in token_freqs}

# %%
from math import log

total_sum = sum([freq for token, freq in token_freqs.items()])
model = {token: -log(freq / total_sum) for token, freq in token_freqs.items()}

# %%
def encode_word(word, model):
    best_segmentations = [{"start": 0, "score": 1}] + [
        {"start": None, "score": None} for _ in range(len(word))
    ]
    for start_idx in range(len(word)):
        # This should be properly filled by the previous steps of the loop
        best_score_at_start = best_segmentations[start_idx]["score"]
        for end_idx in range(start_idx + 1, len(word) + 1):
            token = word[start_idx:end_idx]
            if token in model and best_score_at_start is not None:
                score = model[token] + best_score_at_start
                # If we have found a better segmentation ending at end_idx, we update
                if (
                    best_segmentations[end_idx]["score"] is None
                    or best_segmentations[end_idx]["score"] > score
                ):
                    best_segmentations[end_idx] = {"start": start_idx, "score": score}

    segmentation = best_segmentations[-1]
    if segmentation["score"] is None:
        # We did not find a tokenization of the word -> unknown
        return ["<unk>"], None

    score = segmentation["score"]
    start = segmentation["start"]
    end = len(word)
    tokens = []
    while start != 0:
        tokens.insert(0, word[start:end])
        next_start = best_segmentations[start]["start"]
        end = start
        start = next_start
    tokens.insert(0, word[start:end])
    return tokens, score

# %%
print(encode_word("Concern", model))
print(encode_word("This", model))
# Out:
# (['C', 'o', 'n', 'c', 'e', 'r', 'n'], 28.973186956499674)
# (['T', 'h', 'i', 's'], 20.581325221099362)

# %%
def compute_loss(model):
    loss = 0
    for word, freq in word_freqs.items():
        _, word_loss = encode_word(word, model)
        loss += freq * word_loss
    return loss

# %%
compute_loss(model)
# Out:
# 1849.2243394697016

# %%
import copy


def compute_scores(model):
    scores = {}
    model_loss = compute_loss(model)
    for token, score in model.items():
        # We always keep tokens of length 1
        if len(token) == 1:
            continue
        model_without_token = copy.deepcopy(model)
        _ = model_without_token.pop(token)
        scores[token] = compute_loss(model_without_token) - model_loss
    return scores

# %%
# Check for scores
print(scores)
scores = compute_scores(model)
print(scores["▁e"])
print(scores["▁r"])
# Out:
# {'▁o': 36.2542055260476, '▁r': 28.563919505370677, '▁n': 26.366694928034576, '▁i': 25.268082639366412, '▁t': 25.268082639366412, '▁e': 24.169470350698475, '▁a': 21.972245773362147, '▁s': 13.183347464017288, '▁-': 10.98612288668096, '▁2': 9.887510598012796, '▁c': 9.887510598013023, '▁C': 8.788898309344859, '▁V': 8.788898309344859, '▁d': 8.788898309344859, '▁f': 7.6902860206766945, '▁l': 7.6902860206766945, '▁S': 6.59167373200853, '▁A': 6.59167373200853, '▁O': 6.59167373200853, '▁m': 6.59167373200853, '▁h': 6.59167373200853, '▁u': 5.4930614433405935, '▁p': 5.4930614433405935, '▁g': 4.394449154672429, '▁b': 4.394449154672429, '▁1': 4.394449154672429, '▁R': 3.295836866004265, '▁v': 3.295836866004265, '▁w': 3.295836866004265, '▁y': 2.1972245773363284, '▁W': 2.1972245773363284, '▁k': 2.1972245773363284, '▁T': 2.1972245773363284, '▁M': 2.1972245773363284, '▁I': 2.1972245773363284, '▁D': 2.1972245773363284, '▁9': 2.1972245773363284, '▁0': 2.1972245773363284, '▁/': 2.1972245773363284, '▁:': 1.0986122886681642, '▁E': 1.0986122886681642, '▁Y': 1.0986122886681642, '▁K': 1.0986122886681642, '▁.': 1.0986122886681642, '▁P': 1.0986122886681642, '▁x': 1.0986122886681642, '▁3': 1.0986122886681642}
# 24.169470350698475
# 28.563919505370677

# %%
percent_to_remove = 0.1
while len(model) > 100:
    scores = compute_scores(model)
    sorted_scores = sorted(scores.items(), key=lambda x: x[1])
    # Remove percent_to_remove tokens with the lowest scores.
    for i in range(int(len(model) * percent_to_remove)):
        _ = token_freqs.pop(sorted_scores[i][0])

    total_sum = sum([freq for token, freq in token_freqs.items()])
    model = {token: -log(freq / total_sum) for token, freq in token_freqs.items()}

# %%
def tokenize(text, model):
    words_with_offsets = tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str(text)
    pre_tokenized_text = [word for word, offset in words_with_offsets]
    encoded_words = [encode_word(word, model)[0] for word in pre_tokenized_text]
    return sum(encoded_words, [])

sentences = train_df.iloc[20, 0]
#print(sentences)
sequences = sentences
print(sequences)
context = ' '.join(sequences)
#tokenize(context)

tokenize(context, model)
# Out:
# showed that being diagnosed with SLE was considered a possible protective factor for ICU treatment.12
# ['▁s',
#  '▁h',
#  '▁o',
#  '▁w',
#  '▁e',
#  '▁d',
#  '▁t',
#  '▁h',
#  '▁a',
#  '▁t',
#  '▁b',
#  '▁e',
#  '▁i',
#  '▁n',
#  '▁g',
#  '▁d',
#  '▁i',
#  '▁a',
#  '▁g',
#  '▁n',
#  '▁o',
#  '▁s',
#  '▁e',
#  '▁d',
#  '▁w',
#  '▁i',
#  '▁t',
#  '▁h',
#  '▁S',
#  '<unk>',
#  '▁E',
#  '▁w',
#  '▁a',
#  '▁s',
#  '▁c',
#  '▁o',
#  '▁n',
#  '▁s',
#  '▁i',
#  '▁d',
#  '▁e',
#  '▁r',
#  '▁e',
#  '▁d',
#  '▁a',
#  '▁p',
#  '▁o',
#  '▁s',
#  '▁s',
#  '▁i',
#  '▁b',
#  '▁l',
#  '▁e',
#  '▁p',
#  '▁r',
#  '▁o',
#  '▁t',
#  '▁e',
#  '▁c',
#  '▁t',
#  '▁i',
#  '▁v',
#  '▁e',
#  '▁f',
#  '▁a',
#  '▁c',
#  '▁t',
#  '▁o',
#  '▁r',
#  '▁f',
#  '▁o',
#  '▁r',
#  '▁I',
#  '▁C',
#  '<unk>',
#  '▁t',
#  '▁r',
#  '▁e',
#  '▁a',
#  '▁t',
#  '▁m',
#  '▁e',
#  '▁n',
#  '▁t',
#  '▁.',
#  '▁1',
#  '▁2']
